# %%
import os
os.environ['dburl']="192.168.1.2"
os.environ['username']="mgiraygokirmak"
os.environ['password']="issCli34qki8N0Cu"

# %%
from src.engine import Engine

# %%
engine = Engine()
# Out:
# Wed Jul 13 13:28:11 2022 . Engine Initialized

# %%
engine.read_rates('credit_values')
# Out:
#             bank  amount_range_limit  maturity  interest_rate  min_amount  \
# 0         akbank                1000         3           2.45        1000
# 1         akbank                1000         6           2.45        1000
# 2         akbank                1000         9           2.45        1000
# 3         akbank                1000        12           2.45        1000
# 4         akbank                1000        18           2.48        1000
# ..           ...                 ...       ...            ...         ...
# 169  kuveyt-turk                1000        12           2.43        1000
# 170  kuveyt-turk                1000        18           2.43        1000
# 171  kuveyt-turk                1000        24           2.43        1000
# 172  kuveyt-turk                1000        30           2.43        1000
# 173  kuveyt-turk                1000        36           2.43        1000
#
#      max_amount  min_maturity  max_maturity  fee_pct                date
# ...
